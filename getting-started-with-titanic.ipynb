# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.graph_objects as go
import plotly.express as px
import plotly.offline
from plotly.subplots import make_subplots

# %% [markdown]
# # Loading Data

# %%
# Load Training dataset
train_data = pd.read_csv('/kaggle/input/titanic/train.csv')
test_data = pd.read_csv('/kaggle/input/titanic/test.csv')

# %% [markdown]
# # EDA

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
test_data.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
bar_width = 0.75
colors = []
num_patterns = 30
r = np.mod([val for val in range(100, -150, -int(125*2/10))], 125)
b = np.mod([val for val in range(50, -200, -int(125*2/10))], 125)
g = np.mod([val for val in range(0, 125*2, int(125*2/10))], 125)

for i in range(0,len(r)):
    colors.append('rgba'+ str((r[i],g[i],b[i],0.7)))

# %%
def make_bar_graph(df, col_name, fig, fig_r, fig_c):

    repertoire = df[col_name].unique()
    count = df[col_name].value_counts()
    total = np.sum(count)
    for i in range(0, len(repertoire)):
        annot = str(repertoire[i]) + ' (' + str(count.iloc[i]) + ')'
        fig.add_trace(go.Bar(x=[count.iloc[i]/total], y=[col_name], orientation='h', width=bar_width, text = annot), row=fig_r, col=fig_c)
        #fig.add_trace(go.Bar(x=[count.iloc[i]/total], y=[col_name], orientation='h', width=bar_width, text = annot, marker=dict(color=colors[i])), row=fig_r, col=fig_c)

# %%
fig = make_subplots(rows=1, cols=3, subplot_titles=('Age', 'Fare', 'Categorical data'))

# Histograms for numerical data
fig.add_trace(go.Histogram(x=train_data['Age'], nbinsx=30), row=1, col=1)
fig.add_trace(go.Histogram(x=train_data['Fare'], nbinsx=30), row=1, col=2)

# Bar plots for categorical data

fig_r = 1
fig_c = 3

# -- Survival rate
make_bar_graph(train_data, 'Survived', fig, fig_r,fig_c)
# -- Sex of passengers
make_bar_graph(train_data, 'Sex', fig, fig_r,fig_c)
# -- Class of passengers    
make_bar_graph(train_data, 'Pclass', fig, fig_r,fig_c)    
# -- Siblings / Spouse status of passengers
make_bar_graph(train_data, 'SibSp', fig, fig_r,fig_c)
# -- Parent / Child status of passengers
make_bar_graph(train_data, 'Parch', fig, fig_r,fig_c)


fig.update_layout(barmode='stack', showlegend=False, font=dict(size=15))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
survived = train_data['Survived']==1
dead = train_data['Survived']==0

color_survived = '#242589'
color_dead = '#B92929'

# %%
# Compare the distributions of age of survived passengers and dead passengers
min_age = 0
max_age = max(train_data['Age'])
bin_size = 2

fig_abs = go.Figure()
fig_abs.add_trace(go.Histogram(x=train_data.loc[survived, 'Age'], name='Survived', xbins=dict(start=min_age, end=max_age, size=bin_size), marker_color=color_survived, opacity=0.75))
fig_abs.add_trace(go.Histogram(x=train_data.loc[dead, 'Age'], name='Dead', xbins=dict(start=min_age, end=max_age, size=bin_size), marker_color=color_dead, opacity=0.75))
fig_abs.update_layout(
    title_text='Age of passengers (Absolute numbers)', # title of plot
    xaxis_title_text='Age', # xaxis label
    yaxis_title_text='Num of Samples', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    font=dict(size=15)
)
fig_abs.show()


fig_prob = go.Figure()
fig_prob.add_trace(go.Histogram(x=train_data.loc[survived, 'Age'], histnorm='percent', name='Survived', xbins=dict(start=min_age, end=max_age, size=bin_size), marker_color=color_survived, opacity=0.75))
fig_prob.add_trace(go.Histogram(x=train_data.loc[dead, 'Age'], histnorm='percent', name='Dead', xbins=dict(start=min_age, end=max_age, size=bin_size), marker_color=color_dead, opacity=0.75))
fig_prob.update_layout(
    title_text='Age of passengers (Normalized)', # title of plot
    xaxis_title_text='Age', # xaxis label
    yaxis_title_text='Percent', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1, # gap between bars of the same location coordinates
    font=dict(size=15)
)

fig_prob.show()
# Out:
# <div>                            <div id="3b5d1b89-298c-4ce6-ac86-c812f8504aaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b5d1b89-298c-4ce6-ac86-c812f8504aaa")) {                    Plotly.newPlot(                        "3b5d1b89-298c-4ce6-ac86-c812f8504aaa",                        [{"marker":{"color":"#242589"},"name":"Survived","opacity":0.75,"x":[38.0,26.0,35.0,27.0,14.0,4.0,58.0,55.0,null,null,34.0,15.0,28.0,38.0,null,null,null,null,14.0,3.0,19.0,null,49.0,29.0,null,21.0,5.0,38.0,null,29.0,17.0,32.0,0.83,30.0,29.0,null,17.0,33.0,23.0,23.0,34.0,21.0,null,null,32.5,12.0,24.0,null,29.0,19.0,22.0,24.0,27.0,22.0,16.0,40.0,9.0,null,1.0,1.0,4.0,null,45.0,32.0,19.0,3.0,44.0,58.0,null,18.0,26.0,16.0,40.0,35.0,31.0,27.0,32.0,16.0,38.0,19.0,35.0,5.
# ...

# %%
male_df = train_data.loc[train_data['Sex']=='male','Survived']
n_male_all = len(male_df)
n_male_survived = np.sum(male_df==1)
n_male_dead = np.sum(male_df==0)

female_df = train_data.loc[train_data['Sex']=='female','Survived']
n_female_all = len(female_df)
n_female_survived = np.sum(female_df==1)
n_female_dead = np.sum(female_df==0)


print('Male: Survived=', n_male_survived, ', Dead=', n_male_dead, ', total=', n_male_all)
print('Female: Survived=', n_female_survived, ', Dead=', n_female_dead, ', total=', n_female_all)
# Out:
# Male: Survived= 109 , Dead= 468 , total= 577
# Female: Survived= 233 , Dead= 81 , total= 314

# %%
# Check the effect of gender on the survival

fig = make_subplots(rows=1, cols=2, subplot_titles=('Absolute number of cases', 'Rate'))

# Absolute number of cases 
fig.add_trace(go.Bar(x=['Male','Female'],\
                     y=[n_male_survived, n_female_survived],\
                     text=['Survived ('+str(n_male_survived)+')', 'Survived ('+str(n_female_survived)+')'],\
                     marker_color=color_survived), row=1, col=1)
fig.add_trace(go.Bar(x=['Male','Female'],\
                     y=[n_male_dead, n_female_dead],\
                     text=['Dead ('+str(n_male_dead)+')', 'Dead ('+str(n_female_dead)+')'],\
                     marker_color=color_dead), row=1, col=1)


# Rate
fig.add_trace(go.Bar(x=['Male','Female'],\
                     y=[n_male_survived/n_male_all, n_female_survived/n_female_all],\
                     text=['Survived ('+str(n_male_survived/n_male_all)+')', 'Survived ('+str(n_female_survived/n_female_all)+')'],\
                     marker_color=color_survived), row=1, col=2)
fig.add_trace(go.Bar(x=['Male','Female'],\
                     y=[n_male_dead/n_male_all, n_female_dead/n_female_all],\
                     text=['Dead ('+str(n_male_dead/n_male_all)+')', 'Dead ('+str(n_female_dead/n_female_all)+')'],\
                     marker_color=color_dead), row=1, col=2)


fig.update_layout(barmode='stack', showlegend=False, font=dict(size=15))
fig.show()
# Out:
# <div>                            <div id="7fe28d22-68dd-42c9-ae1d-5bd336ea016b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fe28d22-68dd-42c9-ae1d-5bd336ea016b")) {                    Plotly.newPlot(                        "7fe28d22-68dd-42c9-ae1d-5bd336ea016b",                        [{"marker":{"color":"#242589"},"text":["Survived (109)","Survived (233)"],"x":["Male","Female"],"y":[109,233],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#B92929"},"text":["Dead (468)","Dead (81)"],"x":["Male","Female"],"y":[468,81],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#242589"},"text":["Survived (0.18890814558058924)","Survived (0.7420382165605095)"],"x":["Male","Female"],"y":[0.18890814558058924,0.7420382165605095],"type":"bar"
# ...

# %%
# Check if gender is important to know a passenger's survival

# Women
women = train_data.loc[train_data.Sex == 'female']['Survived']
rate_women = sum(women)/len(women)
print('% of women who survived:', rate_women)

# Men
men = train_data.loc[train_data.Sex == 'male']['Survived']
rate_men = sum(men) / len(men)
print('% of men who survived:', rate_men)
# Out:
# % of women who survived: 0.7420382165605095
# % of men who survived: 0.18890814558058924

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test_data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
table_nan = pd.DataFrame({'Train': train_data.isna().sum(), 'Test': test_data.isna().sum()}) 
table_nan

n = train_data.shape[0]
fig = px.bar(n-table_nan['Train'], title='Number of non-NaN data in Training data ('+str(n)+' samples)')
fig.update_layout(font=dict(size=15))
fig.show()

n = test_data.shape[0]
fig = px.bar(n-table_nan['Test'], title='Number of non-NaN data in Test data ('+str(n)+' samples)')
fig.update_layout(font=dict(size=15))
fig.show()
# Out:
# <div>                            <div id="f93e2dae-9173-4adc-a063-c23a4ff887b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f93e2dae-9173-4adc-a063-c23a4ff887b4")) {                    Plotly.newPlot(                        "f93e2dae-9173-4adc-a063-c23a4ff887b4",                        [{"alignmentgroup":"True","hovertemplate":"variable=Train<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Train","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Train","offsetgroup":"Train","orientation":"v","showlegend":true,"textposition":"auto","x":["Age","Cabin","Embarked","Fare","Name","Parch","PassengerId","Pclass","Sex","SibSp","Survived","Ticket"],"xaxis":"x","y":[714,204,889,891,891,891,891,891,891,891,891,891],"yaxis":"y","type":"b
# ...

# %% [markdown]
# # Create a Gradient Boosted Decision Tree model

# %%
# Create a Gradient Boosting Decesion Tree (GBDT) model
import xgboost as xgb

Y = train_data['Survived']
features = ['Pclass', 'Sex', 'SibSp', 'Parch']
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

dtrain = xgb.DMatrix(X, label=Y)
dtest = xgb.DMatrix(X_test)

# Set hyper parameters
params = {'objective': 'binary:logistic', 'silent':1, 'random_state':1}
num_round = 50

# Training
watchlist = [(dtrain, 'train')]
model_gbdt = xgb.train(params, dtrain, num_round, evals=watchlist)

predictions_gbdt = model_gbdt.predict(dtest)
# Out:
# [01:35:59] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
# [0]	train-logloss:0.57615
# [1]	train-logloss:0.51322
# [2]	train-logloss:0.47600
# [3]	train-logloss:0.45351
# [4]	train-logloss:0.43979
# [5]	train-logloss:0.43059
# [6]	train-logloss:0.42466
# [7]	train-logloss:0.42081
# [8]	train-logloss:0.41804
# [9]	train-logloss:0.41595
# [10]	train-logloss:0.41464
# [11]	train-logloss:0.41323
# [12]	train-logloss:0.41230
# [13]	train-logloss:0.41165
# [14]	train-logloss:0.41097
# [15]	train-logloss:0.41056
# [16]	train-logloss:0.41026
# [17]	train-logloss:0.41003
# [18]	train-logloss:0.40948
# [19]	train-logloss:0.40932
# [20]	train-logloss:0.40878
# [21]	train-logloss:0.40850
# [22]	train-logloss:0.40822
# [23]	train-logloss:0.40795
# [24]	train-logloss:0.40764
# [25]	train-logloss:0.40734
# [26]	train-logloss:0.40710
# [27]	train-logloss:0.40694
# [28]	train-logloss:0.40670
# [29]	train-logloss:0.40658
# [30]	train-logloss:0.40640
# ...

# %% [markdown]
# # Create a Random Forest model

# %%
# Create a Random Forest model

from sklearn.ensemble import RandomForestClassifier

Y = train_data['Survived']
features = ['Pclass', 'Sex', 'SibSp', 'Parch']
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model_rf = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model_rf.fit(X,Y)
predictions_rf = model_rf.predict(X_test)


#output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
#output.to_csv('submission.csv', index=False)
#print('Your submission was successfully saved')

# %%
result_df = pd.DataFrame({"RF": predictions_rf, 'GBDT_boorean': 1*(predictions_gbdt>0.5), 'GBDT_prob': predictions_gbdt})

tmp = [np.nan]*len(X_test)
for i in range(0, len(X_test)):
    
    # When both models agree with the result, use it
    if result_df.loc[i, 'RF'] == result_df.loc[i, 'GBDT_boorean']:
        tmp[i] = result_df.loc[i, 'GBDT_boorean'] 
    # When those models give different results, check the robability of GBDT, and choose the answer of GBDT if its probability is not close to 0.5
    else:
        if (result_df.loc[i, 'GBDT_prob']>=0.75) or (result_df.loc[i, 'GBDT_prob']<=0.25):
            tmp[i] = result_df.loc[i,'GBDT_boorean']
        else:
            tmp[i] = result_df.loc[i,'RF']

output = pd.DataFrame({'PassengerID': test_data['PassengerId'], 'Survived': tmp})
output.to_csv('submission.csv', index=False)
